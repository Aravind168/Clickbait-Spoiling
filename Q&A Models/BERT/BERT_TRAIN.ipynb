# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 21.4 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.1)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.4 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 14.9 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 30.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.9.2

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 56.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.14.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.28.1

# %%
import pandas as pd
import json
from datasets import load_dataset, DatasetDict, load_metric
from transformers import AutoTokenizer
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
from transformers import default_data_collator
from huggingface_hub import notebook_login
from tqdm.auto import tqdm
import numpy as np
import collections

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ## Dataset can be found under the Data folder

# %%
train_data = pd.read_json('/content/train.jsonl',lines=True)
validate_data = pd.read_json('/content/validation.jsonl',lines=True)

# %%
#filter only phrase tags for Q&A task
train_data['tags']=train_data['tags'].apply(lambda x:x[0])
train_data=train_data[train_data['tags']=='phrase'].reset_index(drop=True)

#filter only phrase tags for Q&A task
validate_data['tags']=validate_data['tags'].apply(lambda x:x[0])
validate_data=validate_data[validate_data['tags']=='phrase'].reset_index(drop=True)

# %%
train_data
# Out:
#                                       uuid              postId  \
# 0     b1a1f63d-8853-4a11-89e8-6b2952a393ec  411701128456593408
# 1     008b7b19-0445-4e16-8f9e-075b73f80ca4  380537005123190784
# 2     31b108a3-c828-421a-a4b9-cf651e9ac859  814186311573766144
# 3     46aa8d72-fbd4-4796-a85b-0a0363c21812  841679598526091265
# 4     917e1106-413c-4be5-818b-ad500314feaa  430433533899710464
# ...                                    ...                 ...
# 1362  edec6cde-bbd3-4f50-ba51-ef98bdf19b63              4m7ole
# 1363  84277c0f-4ef1-444e-8e04-55c84af593e5              4lnjcw
# 1364  5b61d712-8b03-4ee6-ba04-b39ce2b206f7  387429931400953856
# 1365  9d05984c-3920-47c0-aa97-8df58cca1fec  826912122529521666
# 1366  0d9e3a31-77f7-414a-9d70-5213f2c0cd94  471834972652048385
#
#                                                postText postPlatform  \
# 0      [NASA sets date for full recovery of ozone hole]      Twitter
# 1     [This is what makes employees happy -- and it'...      Twitter
# 2     [The perfect way to cook rice so that it's per...      Twitter
# 3     [Analysis: This may be the most brutal number ...      Twitter
# 4     [#TeenMom2 star @PBandJenelley_1 reveals the s...      Twitter
# ...                                                 ...          ...
# 1362  [He Dug A Huge Hole In His Backyard, And What ...       reddit
# 1363  [Best Buy Has An Insane Xbox One Deal For A Li...       reddit
# 1364  [Student forced to carry papers to prove she c...      Twitter
# 1365  [You need to see this Twitter account that pre...      Twitter
# 1366       [GOP congressman comes out for gay marriage]      Twitter
#
#                                        targetParagraphs  \
# 0     [2070 is shaping up to be a great year for Mot...
# 1     [Despite common belief, money isn't the key to...
# 2     [Boiling rice may seem simple, but there is a ...
# 3     [Plenty has been made of the big Congressional...
# 4     ["Teen Mom 2" star Jenelle Evans took to Twitt...
# ...                                                 ...
# 1362  [When it comes to home projects, sometimes the...
# 1363  [Best Buy Has An Insane Xbox One Deal For A Li...
# 1364  [She's not a tourist visiting a foreign countr...
# 1365  [What the HELL?!, 1. Unless you’re somewhere w...
# 1366  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Hole In Ozone Layer Expected To Make Full Reco...
# 1     Intellectual Stimulation Trumps Money For Empl...
# 2     Revealed: The perfect way to cook rice so that...
# 3     This may be the most brutal number in the CBO ...
# 4     'Teen Mom 2' Star Jenelle Evans Reveals Sex Of...
# ...                                                 ...
# 1362  He Dug A Huge Hole In His Backyard, And What H...
# 1363  Best Buy Has An Insane Xbox One Deal For A Lim...
# 1364  Melona Clark, Hampton University Student, Carr...
# 1365  WTF, It Looks Like This Twitter Account "Predi...
# 1366  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     2070 is shaping up to be a great year for Moth...
# 1     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 2     The question 'How does one cook rice properly?...
# 3     A 750 percent premium increase for the Trump C...
# 4     "Teen Mom 2" star Jenelle Evans took to Twitte...
# ...                                                 ...
# 1362                                               None
# 1363  For one week only Best Buy has a special $50 o...
# 1364  She's not a tourist visiting a foreign country...
# 1365
# 1366                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0     ozone layer,ozone hole determined by weather,M...
# 1     employee happiness money,employee happiness in...
# 2               Quora,users,share,perfect,way,cook,rice
# 3     ahca, health care, aaron blake, the fix, obama...
# 4     jenelle evans teen mom,jenelle evans,jenelle e...
# ...                                                 ...
# 1362                                               None
# 1363  entertainment news, movie news, movie reviews,...
# 1364  student headscarf university,student hijab col...
# 1365
# 1366  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                             targetMedia  \
# 0     [http://s.m.huffpost.com/assets/Logo_Huffingto...
# 1     [http://i.huffpost.com/gen/1359674/images/o-HA...
# 2                                                  None
# 3                                                  None
# 4     [http://s.m.huffpost.com/assets/Logo_Huffingto...
# ...                                                 ...
# 1362  [https://n-cdn.areyouahuman.com/noscript/a3c26...
# 1363  [http://b.scorecardresearch.com/p?c1=2&c2=2122...
# 1364  [http://i.huffpost.com/gen/1392630/images/n-ME...
# 1365                                               None
# 1366  [http://s.m.huffpost.com/assets/Logo_Huffingto...
#
#                                               targetUrl  \
# 0                                http://huff.to/1cH672Z
# 1                                http://huff.to/1epfeaw
# 2                                                  None
# 3                                                  None
# 4                                http://huff.to/1fFY7QD
# ...                                                 ...
# 1362  https://thedesigninspiration.com/news/awesome/...
# 1363  http://webcache.googleusercontent.com/search?q...
# 1364                             http://huff.to/1bRnSLB
# 1365                                               None
# 1366                             http://huff.to/1kMAadJ
#
#                                              provenance  \
# 0     {'source': 'anonymized', 'humanSpoiler': '2070...
# 1     {'source': 'anonymized', 'humanSpoiler': 'Inte...
# 2     {'source': 'anonymized', 'humanSpoiler': None,...
# 3     {'source': 'anonymized', 'humanSpoiler': None,...
# 4     {'source': 'anonymized', 'humanSpoiler': 'Boy'...
# ...                                                 ...
# 1362  {'source': 'anonymized', 'humanSpoiler': 'Buil...
# 1363  {'source': 'anonymized', 'humanSpoiler': '$50....
# 1364  {'source': 'anonymized', 'humanSpoiler': 'At H...
# 1365  {'source': 'anonymized', 'humanSpoiler': None,...
# 1366  {'source': 'anonymized', 'humanSpoiler': 'Rep....
#
#                                           spoiler        spoilerPositions  \
# 0                                          [2070]      [[[0, 0], [0, 4]]]
# 1                      [intellectual stimulation]  [[[1, 186], [1, 210]]]
# 2                              [in a rice cooker]    [[[5, 60], [5, 76]]]
# 3                                   [750 percent]  [[[2, 109], [2, 120]]]
# 4                                           [boy]  [[[0, 103], [0, 106]]]
# ...                                           ...                     ...
# 1362                    [own underground bunker!]  [[[20, 70], [20, 93]]]
# 1363                                    [$50 off]  [[[8, 101], [8, 108]]]
# 1364  [student at Hampton University in Virginia]     [[[1, 9], [1, 50]]]
# 1365                             [@beyoncefan666]    [[[3, 55], [3, 69]]]
# 1366                  [Rep. Charlie Dent (R-Pa.)]     [[[0, 0], [0, 25]]]
#
#         tags
# 0     phrase
# 1     phrase
# 2     phrase
# 3     phrase
# 4     phrase
# ...      ...
# 1362  phrase
# 1363  phrase
# 1364  phrase
# 1365  phrase
# 1366  phrase
#
# [1367 rows x 14 columns]

# %%
# data processing to get context and spoiler start position
def create_df(dataset):

    col1=[]
    col2=[]

    for idx in range(len(dataset)):
        concatlen=0
        line_occuring=dataset['spoilerPositions'][idx][0][0][0]

        for i in range(line_occuring):
            concatlen+=len(dataset['targetParagraphs'][idx][i])


        starting_position=concatlen+dataset['spoilerPositions'][idx][0][0][1]

        col1.append({'answer_start': [starting_position], 'text': dataset['spoiler'][idx]})

        l=''
        for line in dataset['targetParagraphs'][idx]:
            l+=line
        
        col2.append(l)

    df = pd.DataFrame(list(zip(col1, col2)),
    columns =['answers', 'context'])
    df['question']=dataset['postText'].apply(lambda x: x[0])
    df['id']=dataset['postId']

    json_data=[]
    for index, row in df.iterrows():
        json_data.append({
            'question': row['question'],
            'context': row['context'],
            'answers': row['answers'],
            'id': row['id']
        })

    return json_data

# %%
train_json=create_df(train_data)
validate_json=create_df(validate_data)

with open('train_json.json', 'w') as f:
    json.dump(train_json, f)

with open('validate_json.json', 'w') as f:
    json.dump(validate_json, f)

# %%
# Load the JSON file as a Dataset object
train_dataset = load_dataset('json', data_files='train_json.json')
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-04aef8600e89fc7a/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-04aef8600e89fc7a/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
validate_dataset = load_dataset('json', data_files='validate_json.json')
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-1d98a20b9ee90192/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-1d98a20b9ee90192/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Create a DatasetDict object containing the Dataset
train_dict = DatasetDict({'train': train_dataset['train']})
valid_dict = DatasetDict({'valid': validate_dataset['train']})

# %% [markdown]
# ## Data Pre-Processing

# %%
model = "bert-large-uncased-whole-word-masking-finetuned-squad"
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def prepare_train_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original context. This will
    # help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != (1):
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1):
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
def prepare_validation_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and maybe padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")

    # We keep the example_id that gave us this feature and we will store the offset mappings.
    tokenized_examples["example_id"] = []

    for i in range(len(tokenized_examples["input_ids"])):
        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])

        # Set to None the offset_mapping that are not part of the context so it's easy to determine if a token
        # position is part of the context or not.
        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]

    return tokenized_examples

# %%
batch_size=2
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128 # The authorized overlap between two part of the context when splitting it is needed.

# %%
tokenized_train = train_dict.map(prepare_train_features, batched=True, remove_columns=train_dict["train"].column_names)
tokenized_valid = valid_dict.map(prepare_validation_features, batched=True, remove_columns=valid_dict["valid"].column_names)
# Out:
# Map:   0%|          | 0/1367 [00:00<?, ? examples/s]
# Map:   0%|          | 0/335 [00:00<?, ? examples/s]

# %% [markdown]
# ## Training

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]

# %%
model_name = "bert-large-uncased-whole-word-masking-finetuned-squad"
args = TrainingArguments(
    f"{model_name}-finetuned-squad",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=1,
    weight_decay=0.01,
    push_to_hub=True,
)


data_collator = default_data_collator

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_train["train"],
    eval_dataset=tokenized_valid["valid"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)
# Out:
# Cloning https://huggingface.co/Lahen/bert-large-uncased-whole-word-masking-finetuned-squad-finetuned-squad into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/Lahen/bert-large-uncased-whole-word-masking-finetuned-squad-finetuned-squad into local empty directory.
# Download file pytorch_model.bin:   0%|          | 16.4k/1.24G [00:00<?, ?B/s]
# Download file runs/Apr20_06-39-36_6d9ba7584743/events.out.tfevents.1681972786.6d9ba7584743.269.4: 100%|#######…
# Download file runs/Apr20_23-50-17_cb0004afdd0c/1682034917.095195/events.out.tfevents.1682034917.cb0004afdd0c.1…
# Download file runs/Apr21_02-05-54_19b6b309fc6c/1682043045.9732175/events.out.tfevents.1682043045.19b6b309fc6c.…
# Download file runs/Apr20_19-11-04_f805e3b52715/1682018219.4009156/events.out.tfevents.1682018219.f805e3b52715.…
# Clean file runs/Apr20_06-39-36_6d9ba7584743/events.out.tfevents.1681972786.6d9ba7584743.269.4:  20%|#9        …
# Download file runs/Apr21_07-44-52_8ea0a9ba7587/1682063449.6776736/events.out.tfevents.1682063449.8ea0a9ba7587.…
# Download file runs/Apr20_06-39-36_6d9ba7584743/1681972786.9080622/events.out.tfevents.1681972786.6d9ba7584743.…
# Clean file runs/Apr20_23-50-17_cb0004afdd0c/1682034917.095195/events.out.tfevents.1682034917.cb0004afdd0c.175.…
# Download file runs/Apr20_06-38-58_6d9ba7584743/1681972765.347636/events.out.tfevents.1681972765.6d9ba7584743.2…
# Clean file runs/Apr21_02-05-54_19b6b309fc6c/1682043045.9732175/events.out.tfevents.1682043045.19b6b309fc6c.391…
# Clean file runs/Apr20_19-11-04_f805e3b52715/1682018219.4009156/events.out.tfevents.1682018219.f805e3b52715.191…
# Clean file runs/Apr21_07-44-52_8ea0a9ba7587/1682063449.6776736/events.out.tfevents.1682063449.8ea0a9ba7587.157…
# Clean file runs/Apr20_06-39-36_6d9ba7584743/1681972786.9080622/events.out.tfevents.1681972786.6d9ba7584743.269…
# Clean file runs/Apr20_06-38-58_6d9ba7584743/1681972765.347636/events.out.tfevents.1681972765.6d9ba7584743.269.…
# Download file runs/Apr20_06-38-58_6d9ba7584743/events.out.tfevents.1681972765.6d9ba7584743.269.2: 100%|#######…
# Clean file runs/Apr20_06-38-58_6d9ba7584743/events.out.tfevents.1681972765.6d9ba7584743.269.2:  25%|##4       …
# Download file runs/Apr21_02-05-54_19b6b309fc6c/events.out.tfevents.1682043045.19b6b309fc6c.391.0: 100%|#######…
# Download file runs/Apr21_07-44-52_8ea0a9ba7587/events.out.tfevents.1682063449.8ea0a9ba7587.157.0: 100%|#######…
# Clean file runs/Apr21_02-05-54_19b6b309fc6c/events.out.tfevents.1682043045.19b6b309fc6c.391.0:  20%|#9        …
# Download file runs/Apr20_19-11-04_f805e3b52715/events.out.tfevents.1682018219.f805e3b52715.191.0: 100%|#######…
# Clean file runs/Apr21_07-44-52_8ea0a9ba7587/events.out.tfevents.1682063449.8ea0a9ba7587.157.0:  20%|#9        …
# Download file runs/Apr20_23-50-17_cb0004afdd0c/events.out.tfevents.1682034917.cb0004afdd0c.175.0: 100%|#######…
# Clean file runs/Apr20_19-11-04_f805e3b52715/events.out.tfevents.1682018219.f805e3b52715.191.0:  23%|##2       …
# Download file training_args.bin: 100%|##########| 3.62k/3.62k [00:00<?, ?B/s]
# Clean file runs/Apr20_23-50-17_cb0004afdd0c/events.out.tfevents.1682034917.cb0004afdd0c.175.0:  23%|##2       …
# Clean file training_args.bin:  28%|##7       | 1.00k/3.62k [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/1.24G [00:00<?, ?B/s]

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='1599' max='1599' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1599/1599 23:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.498600</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1599, training_loss=1.6813745552334955, metrics={'train_runtime': 1394.1528, 'train_samples_per_second': 2.293, 'train_steps_per_second': 1.147, 'total_flos': 2226807190374912.0, 'train_loss': 1.6813745552334955, 'epoch': 1.0})

# %% [markdown]
# ## Model

# %%
trainer.save_model("bert-large-trained")
# Out:
# Upload file runs/Apr26_01-07-57_26418966a39c/events.out.tfevents.1682471582.26418966a39c.453.0:   0%|         …
# To https://huggingface.co/Lahen/bert-large-uncased-whole-word-masking-finetuned-squad-finetuned-squad
#    7f0873f..d54d1c3  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Lahen/bert-large-uncased-whole-word-masking-finetuned-squad-finetuned-squad
#    7f0873f..d54d1c3  main -> main

# %%
#!zip -r bert-large-trained.zip '/content/bert-large-trained'

# %% [markdown]
# ## Prediction

# %%
def postprocess_qa_predictions(examples, features, raw_predictions, n_best_size = 20, max_answer_length = 30):
    all_start_logits, all_end_logits = raw_predictions
    # Build a map example to its corresponding features.
    example_id_to_index = {k: i for i, k in enumerate(examples["id"])}
    features_per_example = collections.defaultdict(list)
    for i, feature in enumerate(features):
        features_per_example[example_id_to_index[feature["example_id"]]].append(i)

    # The dictionaries we have to fill.
    predictions = collections.OrderedDict()

    # Logging.
    print(f"Post-processing {len(examples)} example predictions split into {len(features)} features.")

    # Let's loop over all the examples!
    for example_index, example in enumerate(tqdm(examples)):
        # Those are the indices of the features associated to the current example.
        feature_indices = features_per_example[example_index]

        min_null_score = None # Only used if squad_v2 is True.
        valid_answers = []
        
        context = example["context"]
        # Looping through all the features associated to the current example.
        for feature_index in feature_indices:
            # We grab the predictions of the model for this feature.
            start_logits = all_start_logits[feature_index]
            end_logits = all_end_logits[feature_index]
            # This is what will allow us to map some the positions in our logits to span of texts in the original
            # context.
            offset_mapping = features[feature_index]["offset_mapping"]

            # Update minimum null prediction.
            cls_index = features[feature_index]["input_ids"].index(tokenizer.cls_token_id)
            feature_null_score = start_logits[cls_index] + end_logits[cls_index]
            if min_null_score is None or min_null_score < feature_null_score:
                min_null_score = feature_null_score

            # Go through all possibilities for the `n_best_size` greater start and end logits.
            start_indexes = np.argsort(start_logits)[-1 : -n_best_size - 1 : -1].tolist()
            end_indexes = np.argsort(end_logits)[-1 : -n_best_size - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                    # to part of the input_ids that are not in the context.
                    if (
                        start_index >= len(offset_mapping)
                        or end_index >= len(offset_mapping)
                        or offset_mapping[start_index] is None
                        or offset_mapping[end_index] is None
                    ):
                        continue
                    # Don't consider answers with a length that is either < 0 or > max_answer_length.
                    if end_index < start_index or end_index - start_index + 1 > max_answer_length:
                        continue

                    start_char = offset_mapping[start_index][0]
                    end_char = offset_mapping[end_index][1]
                    valid_answers.append(
                        {
                            "score": start_logits[start_index] + end_logits[end_index],
                            "text": context[start_char: end_char]
                        }
                    )
        
        if len(valid_answers) > 0:
            best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
        else:
            # In the very rare edge case we have not a single non-null prediction, we create a fake prediction to avoid
            # failure.
            best_answer = {"text": "", "score": 0.0}
        
        # Let's pick our final answer: the best one or the null answer (only for squad_v2)
        if not True:
            predictions[example["id"]] = best_answer["text"]
        else:
            answer = best_answer["text"] if best_answer["score"] > min_null_score else ""
            predictions[example["id"]] = answer

    return predictions

# %%
raw_predictions = trainer.predict(tokenized_valid['valid'])
final_predictions = postprocess_qa_predictions(valid_dict['valid'], tokenized_valid['valid'], raw_predictions.predictions)
# Out:
# Post-processing 335 example predictions split into 768 features.
#   0%|          | 0/335 [00:00<?, ?it/s]

# %%
final_predictions
# Out:
# OrderedDict([('857559227384160256', ''),
#              ('388301310635671553', 'Sprite'),
#              ('553676574290354177', 'Smoky Paprika-Baked Garbanzo Beans'),
#              ('4kt69b', 'Anthony Bourdain'),
#              ('4wagdb', 'naled'),
#              ('1100188040002123_1123063127714614', ''),
#              ('473452702002065409', ''),
#              ('170016066732231_174009032999601', ''),
#              ('474005518713769985', 'South Dakota'),
#              ('4kq6db', 'Jalapeno Popper Quesarito'),
#              ('438689079539286016', 'Edward Gorey'),
#              ('403757856597372928', 'Rag & Bone'),
#              ('398323375371608064', 'pixie cut'),
#              ('4wennf', 'southern flying squirrel'),
#              ('384053590207119361',
#               "Bob and Dolores Hope's property.As the Los Angeles Times points out, someone showed great interest in Hope's antique cabinet"),
#              ('590544984098635776', 'August 6th'),
#              ('555426985967894529', ''),
#              ('452637109074272256', ''),
#              ('54zbhl', 'The Arizona Republic'),
#              ('379437666896728064', ''),
#              ('1100188040002123_1112661478754779', 'rapamycin'),
#              ('388798300750872576', 'Santa Clara University'),
#              ('671442190967644160', ''),
#              ('484495058884759552', ''),
#              ('4n8r1i', 'Tim Masthay'),
#              ('390958297249247233', 'squash'),
#              ('553532253817806848', '$25K'),
#              ('443941579582353408', ''),
#              ('836506226728947713', 'Crazy Frog'),
#              ('544pwd', 'your face'),
#              ('54inls', 'Amazon'),
#              ('51i904', ''),
#              ('51h5t1', 'Dieffenbachia'),
#              ('4l2he3', 'baby food'),
#              ('832305003567652_880524278745724', 'Kirk Douglass'),
#              ('852964184249835524', '1,4-dioxane'),
#              ('379746538517323776', ''),
#              ('418989757520027649', 'Wyoming'),
#              ('812123578455957504', 'Nvidia'),
#              ('572971196188393472', '2.1'),
#              ('170016066732231_272090746524762', 'giant piece of cardboard'),
#              ('4op73i', ''),
#              ('4kbp5t', 'Fall of the Resistance'),
#              ('590963499171520512', ''),
#              ('385938226277392384', 'Switzerland'),
#              ('380112609607155712', ''),
#              ('4ozh3u', 'make-shift tap shoes'),
#              ('392438344913022976', 'Rick Snyder'),
#              ('410203680223145985', 'two foundations'),
#              ('170016066732231_208703622863475', 'Boxed'),
#              ('405901363873611776', 'arsenic'),
#              ('380536599009705984', '$700 million'),
#              ('50picj', ''),
#              ('4uy3cu', ''),
#              ('376532149887049728', 'Gilbert Arenas'),
#              ('4mx8f0', ''),
#              ('4xiczl', ''),
#              ('375649248525557760', 'Wowzer'),
#              ('4xevbt', ''),
#              ('681204363902238720', '$500,000'),
#              ('405558716897820672', 'never made a dollar'),
#              ('4vdlog', '170 cars'),
#              ('378184351545954305', 'Atlanta'),
#              ('426590828782694400', ''),
#              ('849230685204608_883155208478822', 'the Israelis'),
#              ('397203892938604545', 'Chiwetel Ejiofor'),
#              ('378173406858203136', 'Lviv'),
#              ('881531941974661_904524699675385', 'Alaskan Malamute'),
#              ('376216574828376064', ''),
#              ('800048986762423_811478622286126', 'June 12'),
#              ('388350033805840384', '"ARTPOP'),
#              ('546o7t', ''),
#              ('4jp27b', '$1,000 per haircut'),
#              ('832305003567652_854402051357947',
#               'someone from her not-so-distant past'),
#              ('431829764018810881', 'No perm. No extensions'),
#              ('377644760929824768', 'pantsuits'),
#              ('50accr', ''),
#              ('4tuj89', 'Massachusetts'),
#              ('571535305729310720', 'VLC'),
#              ('455387195051085824', 'Liechtenstein'),
#              ('4j1lgb', 'the restaurant’s manager and co-owner'),
#              ('402132074368225280', '19 warm sweaters'),
#              ('386321975167049728', 'Black Women'),
#              ('846762500372729857', ''),
#              ('832305003567652_857966724334813', 'Take Walks on Beaches'),
#              ('377825111468167170', ''),
#              ('405505043748507648', "I think she's fabulous"),
#              ('557tk3', ''),
#              ('4r9a5c', 'altruism'),
#              ('47rz2v', 'dying his hair sky blue'),
#              ('170016066732231_204801526587018', ''),
#              ('429393582953619456', ''),
#              ('390964121476157440', 'botulinum toxin'),
#              ('395790166058868736', 'Arthur Brooks'),
#              ('4t5reh', 'Antenna Bands'),
#              ('641931005461438464', 'grey tee and blue jeans'),
#              ('4lv7mh', ''),
#              ('845072946053943296', 'Ripcord'),
#              ('411664028734615552', "China's Sichuan Province"),
#              ('696888225395253248', ''),
#              ('4n66f9', '$1,230'),
#              ('849230685204608_878461742281502', ''),
#              ('505545482979561_516236938577082',
#               'Pantone 448 C, or "opaque couché" is a greenish brown-gray'),
#              ('4n1j9c', ''),
#              ('381170307307827200', ''),
#              ('387032239147454464', ''),
#              ('51i0o5', 'Ryan Tannehill'),
#              ('765236645159378944', '$564'),
#              ('374425931613364224', 'realistic optimists'),
#              ('392397011065921536', 'Kevin Elmer'),
#              ('170016066732231_249329898800847', 'spray-on nail polish'),
#              ('962012720563208_1005501169547696', ''),
#              ('604664354747871232', '9 a.m.'),
#              ('854160817360707584', ''),
#              ('800048986762423_809618749138780', 'Sombra'),
#              ('408112290924204034', ''),
#              ('375094646113705985', ''),
#              ('590136994585567232', 'zone-read specialist'),
#              ('379427836500930560', 'one million dollars'),
#              ('517kn6', 'Braconid'),
#              ('832305003567652_851078631690289', '$420,000'),
#              ('385186000726937600', 'Vintage Home Finds'),
#              ('386519747921457152', ''),
#              ('4mq11h', 'becoming the victims'),
#              ('805842201611800576', ''),
#              ('881531941974661_903275403133648', 'Sumatran rhinos'),
#              ('687865017350393856', 'Ted Cruz'),
#              ('4t3qv4', 'a massive asteroid'),
#              ('396395351667531776', ''),
#              ('817631862226989057', 'September 16'),
#              ('501sed', 'Arsène Wenger'),
#              ('4kiig0', ''),
#              ('819113738901004288', ''),
#              ('527b89', 'Guns N’Roses'),
#              ('703213550664290304', 'Donald Trump and Hillary Clinton'),
#              ('378527766309662720', 'El Chavo'),
#              ('549418942511710208', ''),
#              ('4tvvhd', 'hypnotherapy'),
#              ('383314706129108994', 'Elmore Leonard'),
#              ('387703655299678208', 'Monserrat'),
#              ('533272568535711744', '$290 million'),
#              ('812834949669724160', ''),
#              ('855010657883869184', 'Janine Hall'),
#              ('54k7x5', 'Amber Mills'),
#              ('4xo9bv', 'retract and disappear'),
#              ('625634669216854017', ''),
#              ('4qpvuw', 'Trey Songz'),
#              ('5598ba', 'Paperbricks'),
#              ('505545482979561_516860008514775', 'Oregano'),
#              ('170016066732231_229546794112491', ''),
#              ('392311087657279488', 'Ruben Guerrero'),
#              ('170016066732231_242426779491159', 'Ramen'),
#              ('4qjh5h', 'Tawny Kitaen'),
#              ('384228827633041408', ''),
#              ('421379299350810624', 'going for a walk'),
#              ('53zrds', 'The Choking Game'),
#              ('553c0o', 'fears about body fat'),
#              ('433278625488863232', 'Bizzle'),
#              ('380045714526457857', 'Coln River in Gloucestershire'),
#              ('497233573045628928', ''),
#              ('377647990275469312', 'Vince Gill'),
#              ('800048986762423_811976758902979', ''),
#              ('721323075246112769', ''),
#              ('51a6xo', 'Braconid'),
#              ('54dxh0', ''),
#              ('462342339781201920',
#               'John Williams music. To celebrate the fake holiday, Rdio.com has compiled a playlist of selections from Williams\' "Star Wars" scores'),
#              ('4lro2v', ''),
#              ('53e76y', 'Lord Ivar Mountbatten'),
#              ('170016066732231_253847418349095',
#               '"Who is watching your kids?"'),
#              ('392491490242347009', 'Celia Cruz'),
#              ('4jrcgc', '$117 billion'),
#              ('170016066732231_181078432292661', ''),
#              ('432690060711170048', 'Michael Sam'),
#              ('4k1dnt', ''),
#              ('517wb2', 'longline yellow raincoat'),
#              ('403923146090115072', ''),
#              ('393952699391016960', ''),
#              ('4ospl7', ''),
#              ('4wu5zv', ''),
#              ('50zybd', 'textbooks'),
#              ('613054300655218688', 'Austin, Texas'),
#              ('516pm8', ''),
#              ('4qap0d', 'YInMn blue'),
#              ('382166003905331200', ''),
#              ('401040284865146880', '"Parenthood'),
#              ('844109892399324_887681204708859', 'albino raccoon'),
#              ('395049809632964608', 'Jason Aldean'),
#              ('618428639483424768', '1,448.7 days'),
#              ('170016066732231_232214433845727', ''),
#              ('832305003567652_880543728743779', 'Pennsylvania'),
#              ('4moj1o', ''),
#              ('388040438298324992', 'Miley Cyrus'),
#              ('520592421319876608', ''),
#              ('575047627059896321', 'Jussie Smollett'),
#              ('54hbh4', 'Kevin Hart'),
#              ('618393368599597057', '$25,000 per monthS'),
#              ('562692085917425664', ''),
#              ('1100188040002123_1107266289294298', 'a moon'),
#              ('4m49gm', 'Mexico City'),
#              ('849230685204608_883114155149594', 'MS Dhoni'),
#              ('52c61r', '4 mm tumor in her brain'),
#              ('4mo5q3', ''),
#              ('427972855876558848', 'Katy Perry'),
#              ('386267518580424704', 'The Netherlands'),
#              ('170016066732231_220684304998740',
#               'photograph of a doormat glued to two pieces of foam'),
#              ('622416023829020672', ''),
#              ('409836726140805120', 'Peter Pilotto'),
#              ('4klknb', "'Find Donald Trump,'"),
#              ('52k5qq', 'online multiplayer unplayable'),
#              ('554gk6', 'raw apple and raw lettuce'),
#              ('4q3xfu', 'fettuccine Alfredo'),
#              ('4n9cqn', ''),
#              ('459468554631647232', 'Shamus Beaglehole'),
#              ('818496308377833472', 'Wolverampton'),
#              ('4lvqjq', 'colourful igloo'),
#              ('407908413322960897', '29-cent towel'),
#              ('428635906502049792', ''),
#              ('4lvkum', 'a watch'),
#              ('844109892399324_889350541208592', 'dead whale'),
#              ('484865645046407169', '"Destiny"'),
#              ('511088720544821248', 'online gaming'),
#              ('401370516100898816', 'Kim Jong Un impersonator'),
#              ('4lrdjx', 'lack of Internet access'),
#              ('578311702372052994', 'frostbite'),
#              ('375645819648479232', 'José Jose'),
#              ('728601615582662656', 'May 8'),
#              ('443112070146699264',
#               'In a land far, far away sits the restaurant of your dreams.During low tide, you can walk to The Rock'),
#              ('615906959791816704', 'Jackson Vroman'),
#              ('378392279876005888', ''),
#              ('4w69a8', 'potatoes'),
#              ('4ww4tu', 'Taran Killam and Jay Pharoah'),
#              ('54yggl', 'Idaho'),
#              ('4r59nu', ''),
#              ('449296576163618816', '77'),
#              ('4s5gb5', 'penis'),
#              ('380703825654743040', ''),
#              ('52evc0', '$765,759'),
#              ('616067648904896516', 'Oregon'),
#              ('390523516732194816', 'gorgeous house tour'),
#              ('5147nr', 'ambassadorial capacity'),
#              ('384116690037915648', '"Dumb and Dumber To"'),
#              ('54pihs', '.'),
#              ('4t3ohh', ''),
#              ('668487760135782401', ''),
#              ('622578942885687296', 'strawberry rhubarb'),
#              ('559bc3', 'paper bag'),
#              ('426569440109821952', 'Sephora Instant Moisturizer'),
#              ('4we17m', 'Jimmy Smits'),
#              ('646018779005235200',
#               'played outside with her friends Saturday'),
#              ('719302139173072896', 'Laura Bush'),
#              ('4xjied', 'I can’t eat pizza'),
#              ('465028084585234432', 'Colorado'),
#              ('844109892399324_845482578928722',
#               'stacks upon stacks of bills'),
#              ('813127266544873473', 'Tulsiram Manere'),
#              ('5265hx', 'Ailish Sheehan'),
#              ('405553764137840641', 'Chicago'),
#              ('52xko0', 'french fry'),
#              ('810282611591483393', ''),
#              ('832305003567652_889179127880239', ''),
#              ('407878099464769536', 'colleges'),
#              ('547135273948438529', 'Menelik Watson'),
#              ('800048986762423_830793070354681', 'Ana'),
#              ('630010636634836992', 'pears'),
#              ('396020159493570560', 'Blake McIver'),
#              ('414871096408555520', ''),
#              ('414838178827083776', 'a great big belly rub'),
#              ('823752189139034113', ''),
#              ('4wq5y8', ''),
#              ('4ixrkf', '"there will always be exceptions."'),
#              ('505545482979561_526359100898199', ''),
#              ('4k6kkr', 'carried a young girl to safety'),
#              ('556x1o', 'little tab'),
#              ('387043044769267712', 'how to organize your drawers'),
#              ('381046028587503617', 'Ben Bernanke'),
#              ('1100188040002123_1111272498893677', 'sleep deprivation'),
#              ('421783445094690817', 'Feb. 24'),
#              ('170016066732231_256666081400562',
#               'handling their money and talking about it with their partners'),
#              ('820502522343411712', 'polymyalgia rheumatica'),
#              ('4u3b4k', 'as a drink coaster'),
#              ('170016066732231_232215157178988', 'pet'),
#              ('844109892399324_922420374568275', 'iris coloration'),
#              ('4oveaq', 'spy camera'),
#              ('53q1gm', '"racial profiling"'),
#              ('377275214800777216', 'lime green'),
#              ('857281898141405185', ''),
#              ('551ndh', 'pizza'),
#              ('420579512909193216', 'with an acoustic version'),
#              ('4mionu', ''),
#              ('4s7qqd', 'Hot dogs'),
#              ('373517547380826113', 'Chris Pratt'),
#              ('52c6qz', 'rosemary'),
#              ('384901071199817728', '1,080'),
#              ('613393346669772800', 'Google'),
#              ('698190806209921024', 'Intrepid'),
#              ('47n5eu', 'in the MORNINGS'),
#              ('399322475961397248', ''),
#              ('52wcr5', ''),
#              ('800048986762423_827786360655352', '‘capture the pigeon’ mode'),
#              ('857700992179195907', '"Chal Na Katrina"'),
#              ('402650465680490496', 'Monday, February 24'),
#              ('4vh7tm', ''),
#              ('696888948732338176', ''),
#              ('589062531014066177', 'Lawrence Phillips'),
#              ('388756523607797762', 'Carrer Avinyo'),
#              ('676572879064961026', 'Colin Quinn'),
#              ('4pbbod', 'fossil'),
#              ('554ep7', ''),
#              ('1100188040002123_1110492208971706',
#               'the lost and hidden city of Skara Brae'),
#              ('800048986762423_896532303780757', ''),
#              ('4lx1le', ''),
#              ('831194520750546944', ''),
#              ('1100188040002123_1112696008751326', 'water'),
#              ('376543708663283712', ''),
#              ('4mucb0', 'rag'),
#              ('570230039624740864', 'Houston'),
#              ('391248046492635136', 'Elle'),
#              ('830403516636147718', 'Megan Dixon'),
#              ('394888877107716097', 'Chris Crocker'),
#              ('438154712895221761', 'Minnesota'),
#              ('4aung2', 'stealing her jewelry'),
#              ('379438103414718464', 'Cecily Strong'),
#              ('563469314997886977', ''),
#              ('54wzm4', ''),
#              ('530kc0', 'nine tiny puppies'),
#              ('170016066732231_199315770468927',
#               'post-micturition convulsion syndrome'),
#              ('477585615706685440', 'gay'),
#              ('843295362613952512', 'bullshitting'),
#              ('473633855145263105', 'Yvette Nicole Brown'),
#              ('419294849125580800', 'Florida'),
#              ('4o2q65', ''),
#              ('770585517859700736', 'white pepper'),
#              ('595980153529999360', ''),
#              ('4vff7n', ''),
#              ('806153730206892032', ''),
#              ('388308677494444032', 'Richard Belzer')])

# %% [markdown]
# ## Evaluation

# %%
predictions = [ v for k, v in final_predictions.items()]
references = [ex["answers"]["text"] for ex in valid_dict['valid']]

# %%
# remove empty string elements from predictions and references
indices_to_remove = [i for i, p in enumerate(predictions) if p == ""]
for i in reversed(indices_to_remove):
    del predictions[i]
    del references[i]

print(predictions)  
print(references)
# Out:
# ['Sprite', 'Smoky Paprika-Baked Garbanzo Beans', 'Anthony Bourdain', 'naled', 'South Dakota', 'Jalapeno Popper Quesarito', 'Edward Gorey', 'Rag & Bone', 'pixie cut', 'southern flying squirrel', "Bob and Dolores Hope's property.As the Los Angeles Times points out, someone showed great interest in Hope's antique cabinet", 'August 6th', 'The Arizona Republic', 'rapamycin', 'Santa Clara University', 'Tim Masthay', 'squash', '$25K', 'Crazy Frog', 'your face', 'Amazon', 'Dieffenbachia', 'baby food', 'Kirk Douglass', '1,4-dioxane', 'Wyoming', 'Nvidia', '2.1', 'giant piece of cardboard', 'Fall of the Resistance', 'Switzerland', 'make-shift tap shoes', 'Rick Snyder', 'two foundations', 'Boxed', 'arsenic', '$700 million', 'Gilbert Arenas', 'Wowzer', '$500,000', 'never made a dollar', '170 cars', 'Atlanta', 'the Israelis', 'Chiwetel Ejiofor', 'Lviv', 'Alaskan Malamute', 'June 12', '"ARTPOP', '$1,000 per haircut', 'someone from her not-so-distant past', 'No perm. No extensions', 'pantsuits', 'Massachusetts', 'VLC', 'Liechtenstein', 'the restaurant’s manager and co-owner', '19 warm sweaters', 'Black Women', 'Take Walks on Beaches', "I think she's fabulous", 'altruism', 'dying his hair sky blue', 'botulinum toxin', 'Arthur Brooks', 'Antenna Bands', 'grey tee and blue jeans', 'Ripcord', "China's Sichuan Province", '$1,230', 'Pantone 448 C, or "opaque couché" is a greenish brown-gray', 'Ryan Tannehill', '$564', 'realistic optimists', 'Kevin Elmer', 'spray-on nail polish', '9 a.m.', 'Sombra', 'zone-read specialist', 'one million dollars', 'Braconid', '$420,000', 'Vintage Home Finds', 'becoming the victims', 'Sumatran rhinos', 'Ted Cruz', 'a massive asteroid', 'September 16', 'Arsène Wenger', 'Guns N’Roses', 'Donald Trump and Hillary Clinton', 'El Chavo', 'hypnotherapy', 'Elmore Leonard', 'Monserrat', '$290 million', 'Janine Hall', 'Amber Mills', 'retract and disappear', 'Trey Songz', 'Paperbricks', 'Oregano', 'Ruben Guerrero', 'Ramen', 'Tawny Kitaen', 'going for a walk', 'The Choking Game', 'fears about body fat', 'Bizzle', 'Coln River in Gloucestershire', 'Vince Gill', 'Braconid', 'John Williams music. To celebrate the fake holiday, Rdio.com has compiled a playlist of selections from Williams\' "Star Wars" scores', 'Lord Ivar Mountbatten', '"Who is watching your kids?"', 'Celia Cruz', '$117 billion', 'Michael Sam', 'longline yellow raincoat', 'textbooks', 'Austin, Texas', 'YInMn blue', '"Parenthood', 'albino raccoon', 'Jason Aldean', '1,448.7 days', 'Pennsylvania', 'Miley Cyrus', 'Jussie Smollett', 'Kevin Hart', '$25,000 per monthS', 'a moon', 'Mexico City', 'MS Dhoni', '4 mm tumor in her brain', 'Katy Perry', 'The Netherlands', 'photograph of a doormat glued to two pieces of foam', 'Peter Pilotto', "'Find Donald Trump,'", 'online multiplayer unplayable', 'raw apple and raw lettuce', 'fettuccine Alfredo', 'Shamus Beaglehole', 'Wolverampton', 'colourful igloo', '29-cent towel', 'a watch', 'dead whale', '"Destiny"', 'online gaming', 'Kim Jong Un impersonator', 'lack of Internet access', 'frostbite', 'José Jose', 'May 8', 'In a land far, far away sits the restaurant of your dreams.During low tide, you can walk to The Rock', 'Jackson Vroman', 'potatoes', 'Taran Killam and Jay Pharoah', 'Idaho', '77', 'penis', '$765,759', 'Oregon', 'gorgeous house tour', 'ambassadorial capacity', '"Dumb and Dumber To"', '.', 'strawberry rhubarb', 'paper bag', 'Sephora Instant Moisturizer', 'Jimmy Smits', 'played outside with her friends Saturday', 'Laura Bush', 'I can’t eat pizza', 'Colorado', 'stacks upon stacks of bills', 'Tulsiram Manere', 'Ailish Sheehan', 'Chicago', 'french fry', 'colleges', 'Menelik Watson', 'Ana', 'pears', 'Blake McIver', 'a great big belly rub', '"there will always be exceptions."', 'carried a young girl to safety', 'little tab', 'how to organize your drawers', 'Ben Bernanke', 'sleep deprivation', 'Feb. 24', 'handling their money and talking about it with their partners', 'polymyalgia rheumatica', 'as a drink coaster', 'pet', 'iris colo ...
# [['Sprite'], ['Smoky Paprika-Baked Garbanzo Beans'], ['Anthony Bourdain'], ['Dibrom'], ['Stace Nelson'], ['reduced fat sour cream'], ['Edward Gorey'], ['Rag & Bone'], ['pixie cut'], ['southern flying squirrel'], ["Hope's antique cabinet"], ['August 6th'], ['The Arizona Republic'], ['rapamycin'], ['Santa Clara University'], ['Tim Masthay'], ["World's Largest Pumpkin"], ['$25K'], ['Crazy Frog'], ['face'], ['Amazon'], ['Dieffenbachia'], ['baby food'], ['Michael and Kirk'], ['1,4-dioxane'], ['Wyoming'], ['Nvidia'], ['2.1 coffee drinks'], ['giant piece of cardboard'], ['Fall of the Resistance.'], ['Switzerland'], ['make-shift tap shoes'], ['Gov. Rick Snyder (R-Michigan)'], ['two foundations'], ['Boxed'], ['toxic metal arsenic'], ['$900 million'], ['Gilbert Arenas'], ['"Gravity"'], ['Isla Fisher'], ['never received a dime'], ['170'], ['Atlanta'], ['Israel'], ['Chiwetel Ejiofor'], ['Lviv, Ukraine'], ['she joins in'], ['June 12 at 5 PM ET'], ['on "Do What U Want"'], ['$1,000 per haircut'], ['Wiz Khalifa'], ['Long And Healthy'], ['Fashion Advice'], ['Massachusetts'], ['VLC'], ['Liechtenstein'], ['restaurant’s manager and co-owner'], ['sweaters'], ['Black Women'], ['Take Walks on Beaches'], ['"I think she\'s fabulous,"'], ['altruism'], ['dying his hair sky blue'], ['botulinum toxin, "type H"'], ['Arthur Brooks'], ['Antenna Bands'], ['grey tee and blue jeans'], ['Ripcord'], ['Guangyuan, Shanghai'], ['$1,230'], ['Pantone 448 C'], ['Ryan Tannehill'], ['$564'], ['realistic optimists'], ['Rep. Kevin Elmer'], ['spray-on nail polishes'], ['9 a.m.'], ['Sombra'], ['zone-read specialist'], ['one million dollars'], ['Braconid'], ['$420,000'], ['Vintage Home Finds'], ['Lions Die First'], ['second Sumatran rhino'], ['Ted Cruz'], ['asteroid'], ['September 16'], ['Petit'], ['Guns N’ Roses'], ['Clinton'], ['El Chavo'], ['Hypnosis'], ['Elmore Leonard'], ['island of Monserrat'], ['$290 million'], ['Janine Hall'], ['wedding dress'], ['retract and disappear if tampered'], ['Trey Songz'], ['newspaper pulp'], ['Oregano'], ['Ruben Guerrero'], ['Ramen'], ['Tawny Kitaen'], ['going for a walk'], ["'The Choking Game,'"], ['body image issues'], ['Bizzle'], ['Coln River in Gloucestershire'], ['Vince Gill'], ['Braconid'], ['iconic John Williams music'], ['Lord Ivar Mountbatten'], ['"Who is watching your kids?"'], ['Celia Cruz'], ['$117 billion'], ['Michael Sam'], ['yellow'], ['textbooks'], ['Austin, Texas'], ['"YInMn blue."'], ['"Parenthood,"'], ['albino raccoon'], ['Jason Aldean'], ['1,448.7 days'], ['Pennsylvania'], ['Miley Cyrus'], ['Jussie Smollett'], ['Kevin Hart'], ['$25,000 per month'], ['a charcoal-black moon'], ['Mexico City'], ['MS Dhoni'], ['4 mm tumor in her brain'], ['Katy Perry'], ['Netherlands'], ['photograph of a doormat'], ['Peter Pilotto'], ["'Hey Trump, f*** you!'"], ['online multiplayer unplayable'], ['raw apple and raw lettuce'], ['fettuccine Alfredo'], ['Shamus Beaglehole'], ['Wolverampton'], ['colourful igloo'], ['towel'], ['a watch'], ['dead whale'], ['shooter game "Destiny"'], ['online gaming'], ['professional Kim Jong Un impersonator'], ['requested Internet access'], ['frostbite'], ['José José'], ['May 8'], ['The Rock'], ['Jackson Vroman'], ['potatoes'], ['Jay Pharoah and Taran Killam'], ['Idaho'], ['77'], ['penis'], ['$765,759'], ['Oregon'], ['incredible eye for design'], ['in an ambassadorial capacity'], ["'Dumb And Dumber' Sequel"], ['cancer'], ['strawberry rhubarb'], ['paper bag.'], ['Moisturizer'], ['Jimmy Smits'], ['playing hide-and-seek'], ['Laura Bush'], ['pizza'], ['Colorado'], ['money'], ['Tulsiram Manere'], ['she fell'], ['Chicago'], ['french fry'], ['colleges'], ['Menelik Watson'], ['Ana, the kickass heal-sniper'], ['Korean pear juice'], ['Blake McIver'], ['a great big belly rub'], ['"there will always be exceptions."'], ['college graduation'], ['chopsticks holder'], ['great organizational tools'], ['Ben Bernanke'], ['sleep deprivation'], ['Feb. 24'], ['talk about their money'], ['polymyalgia rheumatica'], ['drink coaster'], [ ...

# %% [markdown]
# ### BLEU Score

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
# try with different n-gram orders
i=1
bleuscore = sentence_bleu(references, predictions, weights=[1.1,0,0,0])
print(f'BLEU Score:',bleuscore)
# Out:
# BLEU Score: 0.5824808098281389

# %% [markdown]
# ### METEOR Score

# %%
from datasets import load_metric
meteor = load_metric("meteor")

score = meteor.compute(predictions=predictions, references=references)
alpha=.48
weighted_score = (1 - alpha) * score['meteor'] + alpha * len(predictions) / len(references)

weighted_score
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 0.5524348098932612
